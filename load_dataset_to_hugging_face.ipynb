# %% [markdown]
# <a href="https://colab.research.google.com/github/DylanMontoya/Hackathon-NLP/blob/main/load_dataset_to_hugging_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install argilla -qqq datasets -qqq transformers -qqq

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
import argilla as rg

# %%
rg.init(
    api_url="https://dylanmontoya22-ner-biomedical-text.hf.space",
    api_key="team.apikey"
)

# %%
# save full argilla dataset for reproducibility
rg.load("test_func_tokens_4").to_datasets().push_to_hub("dylanmontoya22/corpus-ner")
# Out:
# ...
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
